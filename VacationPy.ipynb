# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (5.0.5)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: decorator in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: pygments in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.7.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: pickleshare in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (50.3.1.post20201107)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipython-genutils in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: jupyter-core in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.4)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.0.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (19.0.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.1)
# Requirement already satisfied: Send2Trash in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: argon2-cffi in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: prometheus-client in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.4.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: testpath in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: bleach in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: defusedxml in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pycparser in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: packaging in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: async-generator in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tucke\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076102 sha256=4a89cb623d2c62af7689fe85dccbbf154af8f6f5019e31489d5337dc0a0b98eb
#   Stored in directory: c:\users\tucke\appdata\local\pip\cache\wheels\3d\1c\cb\c46f4199210e632b28d78d05a00bfdccbf6dfcd3f5b051d6bf
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import gmaps
import requests
from config import g_key

# %%
city_data_df = pd.read_csv("Weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID                City Country                 Date      Lat  \
# 0        0          Oranjemund     NaN  2021-04-08 11:33:10 -28.5500
# 1        1                Daru      PG  2021-04-08 11:33:11  -9.0763
# 2        2  Puerto Del Rosario      ES  2021-04-08 11:33:11  28.5004
# 3        3               Rawah      IQ  2021-04-08 11:33:12  34.4816
# 4        4                Lasa      IT  2021-04-08 11:33:12  46.6166
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   16.4333     72.84        59           7       10.60
# 1  143.2092     76.33        91          99        9.13
# 2  -13.8627     68.00        73          20        8.05
# 3   41.9093     90.07        12         100       11.41
# 4   10.7002     52.00        38           0        4.61

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp,0) for temp in max_temp], dissipating = False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = city_data_df[['Lat', 'Lng']]
humidity = city_data_df['Humidity']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity = 300, point_radius=4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = city_data_df[['Lat', 'Lng']]
clouds = city_data_df['Cloudiness']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity = 300, point_radius=4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = city_data_df[['Lat', 'Lng']]
wind = city_data_df['Wind Speed']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity = 300, point_radius=4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preffered_cities_df = city_data_df.loc[(city_data_df['Max Temp'] <= max_temp) & (city_data_df['Max Temp'] >= min_temp)]
preffered_cities_df
# Out:
#      City_ID            City Country                 Date      Lat       Lng  \
# 1          1            Daru      PG  2021-04-08 11:33:11  -9.0763  143.2092
# 10        10    Puerto Ayora      EC  2021-04-08 11:33:14  -0.7393  -90.3518
# 12        12         Rikitea      PF  2021-04-08 11:33:15 -23.1203 -134.9692
# 16        16   San Cristobal      VE  2021-04-08 11:33:16   7.7669  -72.2250
# 23        23  Saint-Philippe      RE  2021-04-08 11:33:18 -21.3585   55.7679
# ..       ...             ...     ...                  ...      ...       ...
# 557      557        Monrovia      LR  2021-04-08 11:32:04   6.3005  -10.7969
# 560      560          Macapa      BR  2021-04-08 11:36:39   0.0389  -51.0664
# 561      561          Yulara      AU  2021-04-08 11:36:39 -25.2406  130.9889
# 571      571       Chandbali      IN  2021-04-08 11:36:43  20.7833   86.7667
# 573      573     Kloulklubed      PW  2021-04-08 11:36:44   7.0419  134.2556
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 1       76.33        91          99        9.13
# 10      75.06        91         100        3.22
# 12      76.08        59           1        1.21
# 16      75.20       100          40        2.30
# 23      86.00        62          75       10.36
# ..        ...       ...         ...         ...
# 557     89.60        66          75        9.22
# 560     77.00       100          90        4.61
# 561     75.20        27           5        4.61
# 571     87.17        56          10       18.99
# 573     80.60        89          75        5.57
#
# [183 rows x 10 columns]

# %%
preffered_cities_df = preffered_cities_df.dropna(axis=1)

# %%
preffered_cities_df = preffered_cities_df.reset_index(drop=True)

# %%
preffered_cities_df.head()
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 1         1            Daru      PG  2021-04-08 11:33:11  -9.0763  143.2092
# 10       10    Puerto Ayora      EC  2021-04-08 11:33:14  -0.7393  -90.3518
# 12       12         Rikitea      PF  2021-04-08 11:33:15 -23.1203 -134.9692
# 16       16   San Cristobal      VE  2021-04-08 11:33:16   7.7669  -72.2250
# 23       23  Saint-Philippe      RE  2021-04-08 11:33:18 -21.3585   55.7679
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      76.33        91          99        9.13
# 10     75.06        91         100        3.22
# 12     76.08        59           1        1.21
# 16     75.20       100          40        2.30
# 23     86.00        62          75       10.36

# %%
hotel_df = preffered_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 1             Daru      PG     76.33  -9.0763  143.2092
# 10    Puerto Ayora      EC     75.06  -0.7393  -90.3518
# 12         Rikitea      PF     76.08 -23.1203 -134.9692
# 16   San Cristobal      VE     75.20   7.7669  -72.2250
# 23  Saint-Philippe      RE     86.00 -21.3585   55.7679

# %%
for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    
    params["location"] = f"{lat}, {lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    hotels = requests.get(base_url, params=params).json()
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels['results'][0]['name']
    except (IndexError):
        print('Hotel not found...skipping')
# Out:
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping
# Hotel not found...skipping

# %%
hotel_df.head()
# Out:
#               City Country  Max Temp      Lat       Lng  \
# 1             Daru      PG     76.33  -9.0763  143.2092
# 10    Puerto Ayora      EC     75.06  -0.7393  -90.3518
# 12         Rikitea      PF     76.08 -23.1203 -134.9692
# 16   San Cristobal      VE     75.20   7.7669  -72.2250
# 23  Saint-Philippe      RE     86.00 -21.3585   55.7679
#
#                       Hotel Name
# 1                     Daru Lodge
# 10     Finch Bay Galapagos Hotel
# 12                Pension Maro'i
# 16          Posada Villaven C.A.
# 23  Chambres d'hôte "La Trinité"

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
locations = hotel_df[['Lat', 'Lng']]
max_temp = hotel_df['Max Temp']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
